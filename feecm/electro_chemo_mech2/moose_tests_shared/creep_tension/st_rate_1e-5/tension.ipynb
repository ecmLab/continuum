# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv('tension_out.csv')

# %%
df['engineering_strain']  = df['u_y']/15.5e-3
df['true_stress'] = df['stress_yy']/(1.0 + df['engineering_strain'])

# %%
plt.plot(df['engineering_strain'], df['true_stress']/1e6)

# %%
plt.plot(df['engineering_strain'], df['true_stress']/1e6)
plt.xlim([0,0.002])
# Out:
# (0, 0.002)
